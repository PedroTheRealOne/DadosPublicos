# %%
#Imports usados para analise dos dados
import pandas

# %%
dataset = pandas.read_csv('./Dataset/Criptomoeda.csv', sep=',')

# %%
dataset
# Out:
#               moedas        valor
# 0            Bitcoin  4134.750000
# 1                XRP     0.366946
# 2           Ethereum   116.260000
# 3            Stellar     0.160278
# 4       Bitcoin Cash   172.890000
# 5                EOS     2.930000
# 6           Litecoin    33.870000
# 7             Tether     0.995229
# 8         Bitcoin SV   100.190000
# 9            Cardano     0.041230
# 10            Monero    59.720000
# 11              TRON     0.014880
# 12              IOTA     0.296429
# 13              Dash    92.130000
# 14               NEM     0.077895
# 15      Binance Coin     5.300000
# 16  Ethereum Classic     5.120000
# 17               NEO     8.030000
# 18             Zcash    78.150000
# 19      Bitcoin Gold    18.150000
# 20             Tezos     0.490079
# 21             Maker   393.440000
# 22           VeChain     0.004892
# 23          Dogecoin     0.002235
# 24          Ontology     0.835822
# 25           OmiseGO     1.620000
# ...

# %%
dataset.plot(x='moedas',y='valor',kind='bar', title='Moedas e Preços')

# %%
#Filtrando dados por ordem crescente
dataset.sort_values(by='valor', ascending=False)
# Out:
#               moedas        valor
# 0            Bitcoin  4134.750000
# 21             Maker   393.440000
# 4       Bitcoin Cash   172.890000
# 2           Ethereum   116.260000
# 8         Bitcoin SV   100.190000
# 13              Dash    92.130000
# 18             Zcash    78.150000
# 10            Monero    59.720000
# 6           Litecoin    33.870000
# 30            Decred    20.420000
# 19      Bitcoin Gold    18.150000
# 50            Factom    11.420000
# 52             Augur     8.380000
# 17               NEO     8.030000
# 93             Zcoin     7.170000
# 15      Binance Coin     5.300000
# 16  Ethereum Classic     5.120000
# 89           Elastos     3.110000
# 5                EOS     2.930000
# 98        Crypto.com     2.490000
# 78   Bitcoin Private     2.360000
# 29              Qtum     2.120000
# 51          Populous     1.760000
# 25           OmiseGO     1.620000
# 36             Waves     1.510000
# 33              Lisk     1.460000
# ...
